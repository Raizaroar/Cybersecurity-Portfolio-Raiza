# %% [markdown]
# ## Security Log Analysis
# Author: Raiza Rosas
#
# This notebook simulates the detection of alerts in access logs for a SOC environment.

# %%
import sys
print("Hola Raiza, tu Versión de Python es: ", sys.version)
# Out:
# Hola Raiza, tu Versión de Python es:  3.11.14 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 18:30:03) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ## Input data
#
# We will use a list of simulated records representing attempts to access the system.

# %%
logs = [
    "2026-02-02 15:40:12 - ALERT: Failed access attempt from 192.168.1.50",
    "2026-02-02 15:41:05 - INFO: User admin logged in successfully",
    "2026-02-02 15:42:33 - ALERT: Multiple login attempts from 10.0.0.23"
]
logs[:3]  # show the first records
# Out:
# ['2026-02-02 15:40:12 - ALERT: Failed access attempt from 192.168.1.50',
#  '2026-02-02 15:41:05 - INFO: User admin logged in successfully',
#  '2026-02-02 15:42:33 - ALERT: Multiple login attempts from 10.0.0.23']
